# %%
import mxnet as mx
p = mx.image.imdecode(open('./MIT人脸库/faces/004998.bmp','rb').read(),flag=0)
pp = p.asnumpy()
print(p.asnumpy())
print(p.asnumpy().reshape(1,20,20))
# Out:
# [[[ 10]
#   [  6]
#   [ 20]
#   [ 16]
#   [ 29]
#   [ 56]
#   [ 84]
#   [122]
#   [142]
#   [168]
#   [176]
#   [192]
#   [180]
#   [133]
#   [115]
#   [112]
#   [129]
#   [133]
#   [119]
#   [ 87]]
#
#  [[ 14]
#   [  8]
#   [ 26]
#   [ 20]
#   [ 31]
#   [ 53]
#   [ 98]
#   [147]
#   [168]
#   [180]
#   [168]
#   [ 98]
#   [ 45]
#   [ 37]
#   [ 51]
#   [ 92]
#   [168]
#   [172]
#   [112]
#   [125]]
#
#  [[ 22]
#   [ 24]
#   [ 42]
#   [ 38]
#   [ 35]
#   [ 37]
#   [ 57]
#   [133]
#   [186]
#   [186]
#   [142]
#   [ 75]
#   [ 65]
#   [ 73]
#   [ 82]
#   [ 79]
#   [103]
#   [129]
#   [137]
#   [137]]
#
#  [[ 20]
#   [ 32]
#   [ 48]
#   [ 50]
#   [ 50]
#   [ 60]
#   [ 79]
#   [119]
#   [180]
#   [198]
#   [154]
#   [ 92]
#   [ 78]
#   [ 46]
#   [ 24]
#   [ 27]
#   [ 42]
#   [ 63]
#   [ 98]
#   [122]]
#
#  [[ 21]
#   [ 33]
#   [ 40]
#   [ 31]
#   [ 39]
#   [ 23]
#   [ 37]
#   [ 84]
#   [176]
#   [198]
#   [147]
#   [ 98]
#   [ 55]
#   [ 59]
#   [ 34]
#   [ 30]
#   [ 47]
#   [ 54]
#   [ 98]
#   [125]]
#
#  [[ 17]
#   [ 45]
#   [ 55]
#   [ 51]
#   [ 63]
#   [ 54]
#   [ 62]
#   [ 92]
#   [147]
#   [203]
#   [147]
#   [122]
#   [107]
#   [ 78]
#   [ 80]
#   [103]
#   [ 92]
#   [125]
#   [162]
#   [186]]
#
#  [[ 15]
#   [194]
#   [198]
#   [129]
#   [115]
#   [103]
#   [125]
#   [129]
#   [201]
#   [231]
#   [180]
#   [154]
#   [180]
#   [176]
#   [138]
#   [147]
#   [190]
#   [215]
#   [245]
#   [241]]
#
#  [[ 13]
#   [241]
#   [232]
#   [215]
#   [205]
#   [201]
#   [198]
#   [172]
#   [237]
#   [252]
#   [228]
#   [205]
#   [194]
#   [210]
#   [222]
#   [242]
#   [251]
#   [247]
#   [233]
#   [227]]
#
#  [[ 13]
#   [242]
#   [247]
#   [249]
#   [251]
#   [225]
#   [208]
#   [217]
#   [255]
#   [254]
#   [239]
#   [222]
#   [228]
#   [239]
#   [247]
#   [249]
#   [247]
#   [234]
#   [219]
#   [214]]
#
#  [[  8]
#   [222]
#   [241]
#   [245]
#   [245]
#   [224]
#   [190]
#   [245]
#   [254]
#   [255]
#   [239]
#   [239]
#   [220]
#   [203]
#   [234]
#   [235]
#   [231]
#   [218]
#   [208]
#   [186]]
#
#  [[  4]
#   [ 68]
#   [227]
#   [229]
#   [219]
#  [ 21  33  40  31  39  23  37  84 176 198 147  98  55  59  34  30  47  54
#    98 125]
#  [ 17  45  55  51  63  54  62  92 147 203 147 122 107  78  80 103  92 125
#   162 186]
#  [ 15 194 198 129 115 103 125 129 201 231 180 154 180 176 138 147 190 215
#   245 241]
#  [ 13 241 232 215 205 201 198 172 237 252 228 205 194 210 222 242 251 247
#   233 227]
#  [ 13 242 247 249 251 225 208 217 255 254 239 222 228 239 247 249 247 234
#   219 214]
#  [  8 222 241 245 245 224 190 245 254 255 239 239 220 203 234 235 231 218
#   208 186]
#  [  4  68 227 229 219 192 129 249 237 229 212 232 210  92 186 214 212 198
#   186 176]
#  [  4  26 205 211 192  98  98  75 107 162  98  66  71 107  98 172 190 186
#   180 168]
#  [  2  13  87 147 142  69 107 201 112  87  80  87 103 122 115  78 112 172
#   172 154]
#  [  4   3  40 119 125  75 107 224 112 119 107  98  87 115  82  47  62 154
#   154 154]
#  [  2  10   8 107 137 112  69  38 147 142 133 215 190 186  58  29  82 162
#   162 162]
#  [  6   1  20  27 137 162 162  68  68 133 190 200  60  42  52  75 119 154
#   176 168]
#  [ 17   5  10  13  52 142 176 198 208 186 112  84  78  73  92 137 142 168
#   168 162]
#  [ 43  15  13  20  43  71 137 208 216 154 115 103 103 137 154 162 147 172
#   147 129]
#  [172  28  22  26  58  33  92 203 235 222 200 162 186 194 190 168 162 154
#   129 115]
#  [225  50  34  64  44  62  71  68 227 252 252 218 210 208 194 162 162 122
#   103  65]]

# %%
import mxnet as mx
import os
data_true_dir = '/Users/haowei/Downloads/MIT人脸库/faces/'
data_false_dir = '/Users/haowei/Downloads/MIT人脸库/nonfaces/'
face = {}
face['data'] = []
for i in os.listdir(data_true_dir):
    file_path = os.path.join(data_true_dir,i)
    try:
        with open(file_path,'rb') as f:
            img_s = f.read()
            p = mx.image.imdecode(img_s,flag=0).asnumpy().reshape(1,20,20)
            face['data'].append((p,1))
    except:
        print(file_path)
print(len(face['data']))
for i in os.listdir(data_false_dir):
    file_path = os.path.join(data_false_dir,i)
    try:
        with open(file_path,'rb') as f:
            img_s = f.read()
            p = mx.image.imdecode(img_s,flag=0).asnumpy().reshape(1,20,20)
            face['data'].append((p,0))
    except:
        print(file_path)
print(len(face['data']))
# Out:
# /Users/haowei/Downloads/MIT人脸库/faces/Thumbs.db
# 2706
# /Users/haowei/Downloads/MIT人脸库/nonfaces/Thumbs.db
# 7087

# %%
import random
random.shuffle(face['data'])

# %%
for i in range(10):
    print(face['data'][i][1])
# Out:
# 0
# 0
# 0
# 1
# 0
# 1
# 1
# 0
# 0
# 1

# %%
cropus = {}
import numpy as np
l_of_test = len(face['data'])/10
for i in ['train_data','train_label','test_data','test_label']:
    cropus[i] = []
for i,d in enumerate(face['data']):
    if i < l_of_test:
        cropus['test_data'].append(d[0])
        cropus['test_label'].append(d[1])
    else:
        cropus['train_data'].append(d[0])
        cropus['train_label'].append(d[1])
for i in ['train_data','train_label','test_data','test_label']:
    print(len(cropus[i]))
    cropus[i] = np.asarray(cropus[i])
# Out:
# 6378
# 6378
# 709
# 709

# %%
batch_size = 32
train_iter = mx.io.NDArrayIter(cropus['train_data'], cropus['train_label'], batch_size, shuffle=True)
val_iter = mx.io.NDArrayIter(cropus['test_data'], cropus['test_label'], batch_size)

# %%
import numpy as np
nt = np.asarray(mnist['train_data'])
print(mnist['train_label'])
ntp = nt.reshape(60000,28,28,1)
# Out:
# [5 0 4 ..., 5 6 8]

# %% [markdown]
# After running the above source code, the entire MNIST dataset should be fully loaded into memory. Note that for large datasets it is not feasible to pre-load the entire dataset first like we did here. What is needed is a mechanism by which we can quickly and efficiently stream data directly from the source. MXNet Data iterators come to the rescue here by providing exactly that. Data iterator is the mechanism by which we feed input data into an MXNet training algorithm and they are very simple to initialize and use and are optimized for speed. During training, we typically process training samples in small batches and over the entire training lifetime will end up processing each training example multiple times. In this tutorial, we'll configure the data iterator to feed examples in batches of 100. Keep in mind that each example is a 28x28 grayscale image and the corresponding label.
#
# Image batches are commonly represented by a 4-D array with shape `(batch_size, num_channels, width, height)`. For the MNIST dataset, since the images are grayscale, there is only one color channel. Also, the images are 28x28 pixels, and so each image has width and height equal to 28. Therefore, the shape of input is `(batch_size, 1, 28, 28)`. Another important consideration is the order of input samples. When feeding training examples, it is critical that we don't feed samples with the same label in succession. Doing so can slow down training.
# Data iterators take care of this by randomly shuffling the inputs. Note that we only need to shuffle the training data. The order does not matter for test data.
#
# The following source code initializes the data iterators for the MNIST dataset. Note that we initialize two iterators: one for train data and one for test data.

# %% [markdown]
# ## Training
# We will cover a couple of approaches for performing the hand written digit recognition task. The first approach makes use of a traditional deep neural network architecture called Multilayer Percepton (MLP). We'll discuss its drawbacks and use that as a motivation to introduce a second more advanced approach called Convolution Neural Network (CNN) that has proven to work very well for image classification tasks.
#
# ### Multilayer Perceptron
#
# The first approach makes use of a [Multilayer Perceptron](https://en.wikipedia.org/wiki/Multilayer_perceptron) to solve this problem. We'll define the MLP using MXNet's symbolic interface. We begin by creating a place holder variable for the input data. When working with an MLP, we need to flatten our 28x28 images into a flat 1-D structure of 784 (28 * 28) raw pixel values. The order of pixel values in the flattened vector does not matter as long as we are being consistent about how we do this across all images.

# %%
data = mx.sym.var('data')
# Flatten the data from 4-D shape into 2-D (batch_size, num_channel*width*height)
data = mx.sym.flatten(data=data)

# %% [markdown]
# One might wonder if we are discarding valuable information by flattening. That is indeed true and we'll cover this more when we talk about convolutional neural networks where we preserve the input shape. For now, we'll go ahead and work with flattened images.
#
# MLPs contains several fully connected layers. A fully connected layer or FC layer for short, is one where each neuron in the layer is connected to every neuron in its preceding layer. From a linear algebra perspective, an FC layer applies an [affine transform](https://en.wikipedia.org/wiki/Affine_transformation) to the *n x m* input matrix *X* and outputs a matrix *Y* of size *n x k*, where *k* is the number of neurons in the FC layer. *k* is also referred to as the hidden size. The output *Y* is computed according to the equation *Y = W X + b*. The FC layer has two learnable parameters, the *m x k* weight matrix *W* and the *m x 1* bias vector *b*.
#
#
# In an MLP, the outputs of most FC layers are fed into an activation function, which applies an element-wise non-linearity. This step is critical and it gives neural networks the ability to classify inputs that are not linearly separable. Common choices for activation functions are sigmoid, tanh, and [rectified linear unit](https://en.wikipedia.org/wiki/Rectifier_%28neural_networks%29) (ReLU). In this example, we'll use the ReLU activation function which has several desirable properties and is typically considered a default choice.
#
# The following code declares two fully connected layers with 128 and 64 neurons each. Furthermore, these FC layers are sandwiched between ReLU activation layers each one responsible for performing an element-wise ReLU transformation on the FC layer output.

# %%
# The first fully-connected layer and the corresponding activation function
fc1  = mx.sym.FullyConnected(data=data, num_hidden=128)
act1 = mx.sym.Activation(data=fc1, act_type="relu")

# The second fully-connected layer and the corresponding activation function
fc2  = mx.sym.FullyConnected(data=act1, num_hidden = 64)
act2 = mx.sym.Activation(data=fc2, act_type="relu")

# %% [markdown]
# The last fully connected layer often has its hidden size equal to the number of output classes in the dataset. The activation function for this layer will be the softmax function. The Softmax layer maps its input to a probability score for each class of output. During the training stage, a loss function computes the [cross entropy](https://en.wikipedia.org/wiki/Cross_entropy) between the probability distribution (softmax output) predicted by the network and the true probability distribution given by the label.
#
# The following source code declares the final fully connected layer of size 10. 10 incidentally is the total number of digits. The output from this layer is fed into a `SoftMaxOutput` layer that performs softmax and cross-entropy loss computation in one go. Note that loss computation only happens during training.

# %%
# MNIST has 10 classes
fc3  = mx.sym.FullyConnected(data=act2, num_hidden=2)
# Softmax with cross entropy loss
mlp  = mx.sym.SoftmaxOutput(data=fc3, name='softmax')

# %% [markdown]
# ![png](https://raw.githubusercontent.com/dmlc/web-data/master/mxnet/image/mlp_mnist.png)
#
# **Figure 2:** MLP network architecture for MNIST.
#
# Now that both the data iterator and neural network are defined, we can commence training. Here we'll employ the `module` feature in MXNet which provides a high-level abstraction for running training and inference on predefined networks. The module API allows the user to specify appropriate parameters that control how the training proceeds.
#
# The following source code initializes a module to train the MLP network we defined above. For our training, we will make use of the stochastic gradient descent (SGD) optimizer. In particular, we'll be using mini-batch SGD. Standard SGD processes train data one example at a time. In practice, this is very slow and one can speed up the process by processing examples in small batches. In this case, our batch size will be 100, which is a reasonable choice. Another parameter we select here is the learning rate, which controls the step size the optimizer takes in search of a solution. We'll pick a learning rate of 0.1, again a reasonable choice. Settings such as batch size and learning rate are what are usually referred to as hyper-parameters. What values we give them can have a great impact on training performance. For the purpose of this tutorial, we'll start with some reasonable and safe values. In other tutorials, we'll discuss how one might go about finding a combination of hyper-parameters for optimal model performance.
#
# Typically, one runs the training until convergence, which means that we have learned a good set of model parameters (weights + biases) from the train data. For the purpose of this tutorial, we'll run training for 10 epochs and stop. An epoch is one full pass over the entire train data.

# %%
import logging
logging.getLogger().setLevel(logging.DEBUG)  # logging to stdout
# create a trainable module on CPU
mlp_model = mx.mod.Module(symbol=mlp, context=mx.cpu())
mlp_model.fit(train_iter,  # train data
              eval_data=val_iter,  # validation data
              optimizer='AdaDelta',  # use SGD to train
              eval_metric='acc',  # report accuracy during training
              batch_end_callback = mx.callback.Speedometer(batch_size, 100), # output progress for each 100 data batches
              num_epoch=200)  # train for at most 10 dataset passes
# Out:
# INFO:root:Epoch[0] Batch [100]	Speed: 7602.76 samples/sec	accuracy=0.604270
# INFO:root:Epoch[0] Train-accuracy=0.616477
# INFO:root:Epoch[0] Time cost=0.827
# INFO:root:Epoch[0] Validation-accuracy=0.663043
# INFO:root:Epoch[1] Batch [100]	Speed: 7398.04 samples/sec	accuracy=0.610458
# INFO:root:Epoch[1] Train-accuracy=0.616477
# INFO:root:Epoch[1] Time cost=0.843
# INFO:root:Epoch[1] Validation-accuracy=0.663043
# INFO:root:Epoch[2] Batch [100]	Speed: 7463.28 samples/sec	accuracy=0.610458
# INFO:root:Epoch[2] Train-accuracy=0.616477
# INFO:root:Epoch[2] Time cost=0.840
# INFO:root:Epoch[2] Validation-accuracy=0.663043
# INFO:root:Epoch[3] Batch [100]	Speed: 7387.06 samples/sec	accuracy=0.610458
# INFO:root:Epoch[3] Train-accuracy=0.616477
# INFO:root:Epoch[3] Time cost=0.831
# INFO:root:Epoch[3] Validation-accuracy=0.663043
# INFO:root:Epoch[4] Batch [100]	Speed: 7622.78 samples/sec	accuracy=0.610458
# INFO:root:Epoch[4] Train-accuracy=0.616477
# INFO:root:Epoch[4] Time cost=0.806
# INFO:root:Epoch[4] Validation-accuracy=0.663043
# INFO:root:Epoch[5] Batch [100]	Speed: 7560.29 samples/sec	accuracy=0.610458
# INFO:root:Epoch[5] Train-accuracy=0.616477
# INFO:root:Epoch[5] Time cost=0.814
# INFO:root:Epoch[5] Validation-accuracy=0.663043
# INFO:root:Epoch[6] Batch [100]	Speed: 7583.73 samples/sec	accuracy=0.610458
# INFO:root:Epoch[6] Train-accuracy=0.616477
# INFO:root:Epoch[6] Time cost=0.820
# INFO:root:Epoch[6] Validation-accuracy=0.663043
# INFO:root:Epoch[7] Batch [100]	Speed: 7862.30 samples/sec	accuracy=0.610458
# INFO:root:Epoch[7] Train-accuracy=0.616477
# INFO:root:Epoch[7] Time cost=0.803
# INFO:root:Epoch[7] Validation-accuracy=0.663043
# INFO:root:Epoch[8] Batch [100]	Speed: 7455.28 samples/sec	accuracy=0.610458
# INFO:root:Epoch[8] Train-accuracy=0.616477
# INFO:root:Epoch[8] Time cost=0.815
# INFO:root:Epoch[8] Validation-accuracy=0.663043
# INFO:root:Epoch[9] Batch [100]	Speed: 6280.57 samples/sec	accuracy=0.610458
# INFO:root:Epoch[9] Train-accuracy=0.616477
# INFO:root:Epoch[9] Time cost=1.213
# INFO:root:Epoch[9] Validation-accuracy=0.663043
# INFO:root:Epoch[10] Batch [100]	Speed: 3563.19 samples/sec	accuracy=0.610458
# INFO:root:Epoch[10] Train-accuracy=0.616477
# INFO:root:Epoch[10] Time cost=1.575
# INFO:root:Epoch[10] Validation-accuracy=0.663043
# INFO:root:Epoch[11] Batch [100]	Speed: 4963.43 samples/sec	accuracy=0.610458
# INFO:root:Epoch[11] Train-accuracy=0.616477
# INFO:root:Epoch[11] Time cost=1.205
# INFO:root:Epoch[11] Validation-accuracy=0.663043
# INFO:root:Epoch[12] Batch [100]	Speed: 7272.03 samples/sec	accuracy=0.610458
# INFO:root:Epoch[12] Train-accuracy=0.616477
# INFO:root:Epoch[12] Time cost=0.854
# INFO:root:Epoch[12] Validation-accuracy=0.663043
# INFO:root:Epoch[13] Batch [100]	Speed: 7730.10 samples/sec	accuracy=0.610458
# INFO:root:Epoch[13] Train-accuracy=0.616477
# INFO:root:Epoch[13] Time cost=0.795
# INFO:root:Epoch[13] Validation-accuracy=0.663043
# INFO:root:Epoch[14] Batch [100]	Speed: 8275.26 samples/sec	accuracy=0.610458
# INFO:root:Epoch[14] Train-accuracy=0.616477
# INFO:root:Epoch[14] Time cost=0.763
# INFO:root:Epoch[14] Validation-accuracy=0.663043
# INFO:root:Epoch[15] Batch [100]	Speed: 8040.22 samples/sec	accuracy=0.610458
# INFO:root:Epoch[15] Train-accuracy=0.616477
# INFO:root:Epoch[15] Time cost=0.794
# INFO:root:Epoch[15] Validation-accuracy=0.663043
# INFO:root:Epoch[16] Batch [100]	Speed: 7400.44 samples/sec	accuracy=0.610458
# INFO:root:Epoch[16] Train-accuracy=0.616477
# INFO:root:Epoch[16] Time cost=1.099
# INFO:root:Epoch[16] Validation-accuracy=0.663043
# INFO:root:Epoch[17] Batch [100]	Speed: 3343.04 samples/sec	accuracy=0.610458
# INFO:root:Epoch[17] Train-accuracy=0.616477
# INFO:root:Epoch[17] Time cost=1.511
# INFO:root:Epoch[17] Validation-accuracy=0.663043
# INFO:root:Epoch[18] Batch [100]	Speed: 7612.82 samples/sec	accuracy=0.610458
# INFO:root:Epoch[18] Train-accuracy=0.616477
# INFO:root:Epoch[18] Time cost=0.796
# INFO:root:Epoch[18] Validation-accuracy=0.663043
# INFO:root:Epoch[19] Batch [100]	Speed: 7197.19 samples/sec	accuracy=0.610458
# INFO:root:Epoch[19] Train-accuracy=0.616477
# INFO:root:Epoch[19] Time cost=1.413
# INFO:root:Epoch[19] Validation-accuracy=0.663043
# INFO:root:Epoch[20] Batch [100]	Speed: 4925.68 samples/sec	accuracy=0.610458
# INFO:root:Epoch[20] Train-accuracy=0.616477
# INFO:root:Epoch[20] Time cost=1.433
# INFO:root:Epoch[20] Validation-accuracy=0.663043
# INFO:root:Epoch[21] Batch [100]	Speed: 5289.98 samples/sec	accuracy=0.610458
# INFO:root:Epoch[21] Train-accuracy=0.616477
# INFO:root:Epoch[21] Time cost=1.193
# INFO:root:Epoch[21] Validation-accuracy=0.663043
# INFO:root:Epoch[22] Batch [100]	Speed: 5895.05 samples/sec	accuracy=0.610458
# INFO:root:Epoch[22] Train-accuracy=0.616477
# INFO:root:Epoch[22] Time cost=1.153
# INFO:root:Epoch[22] Validation-accuracy=0.663043
# INFO:root:Epoch[23] Batch [100]	Speed: 7954.96 samples/sec	accuracy=0.610458
# INFO:root:Epoch[23] Train-accuracy=0.616477
# INFO:root:Epoch[23] Time cost=0.852
# INFO:root:Epoch[23] Validation-accuracy=0.663043
# INFO:root:Epoch[24] Batch [100]	Speed: 5617.43 samples/sec	accuracy=0.610458
# INFO:root:Epoch[24] Train-accuracy=0.616477
# INFO:root:Epoch[24] Time cost=1.044
# INFO:root:Epoch[24] Validation-accuracy=0.663043
# INFO:root:Epoch[25] Batch [100]	Speed: 5833.49 samples/sec	accuracy=0.610458
# INFO:root:Epoch[25] Train-accuracy=0.616477
# INFO:root:Epoch[25] Time cost=1.679
# INFO:root:Epoch[25] Validation-accuracy=0.663043
# INFO:root:Epoch[26] Batch [100]	Speed: 7337.38 samples/sec	accuracy=0.610458
# INFO:root:Epoch[26] Train-accuracy=0.616477
# INFO:root:Epoch[26] Time cost=1.064
# INFO:root:Epoch[26] Validation-accuracy=0.663043
# INFO:root:Epoch[27] Batch [100]	Speed: 6829.67 samples/sec	accuracy=0.610458
# INFO:root:Epoch[27] Train-accuracy=0.616477
# INFO:root:Epoch[27] Time cost=1.390
# INFO:root:Epoch[27] Validation-accuracy=0.663043
# INFO:root:Epoch[28] Batch [100]	Speed: 5416.94 samples/sec	accuracy=0.610458
# INFO:root:Epoch[28] Train-accuracy=0.616477
# INFO:root:Epoch[28] Time cost=0.990
# INFO:root:Epoch[28] Validation-accuracy=0.663043
# INFO:root:Epoch[29] Batch [100]	Speed: 6015.60 samples/sec	accuracy=0.610458
# INFO:root:Epoch[29] Train-accuracy=0.616477
# INFO:root:Epoch[29] Time cost=1.265
# INFO:root:Epoch[29] Validation-accuracy=0.663043
# INFO:root:Epoch[30] Batch [100]	Speed: 7481.27 samples/sec	accuracy=0.610458
# INFO:root:Epoch[30] Train-accuracy=0.616477
# INFO:root:Epoch[30] Time cost=0.862
# INFO:root:Epoch[30] Validation-accuracy=0.663043
# INFO:root:Epoch[31] Batch [100]	Speed: 4575.85 samples/sec	accuracy=0.610458
# INFO:root:Epoch[31] Train-accuracy=0.616477
# INFO:root:Epoch[31] Time cost=1.335
# INFO:root:Epoch[31] Validation-accuracy=0.663043
# INFO:root:Epoch[32] Batch [100]	Speed: 4790.63 samples/sec	accuracy=0.610458
# INFO:root:Epoch[32] Train-accuracy=0.616477
# INFO:root:Epoch[32] Time cost=1.344
# INFO:root:Epoch[32] Validation-accuracy=0.663043
# INFO:root:Epoch[33] Batch [100]	Speed: 5524.34 samples/sec	accuracy=0.610458
# INFO:root:Epoch[33] Train-accuracy=0.616477
# INFO:root:Epoch[33] Time cost=1.168
# INFO:root:Epoch[33] Validation-accuracy=0.663043
# INFO:root:Epoch[34] Batch [100]	Speed: 4823.85 samples/sec	accuracy=0.610458
# INFO:root:Epoch[34] Train-accuracy=0.616477
# INFO:root:Epoch[34] Time cost=1.417
# INFO:root:Epoch[34] Validation-accuracy=0.663043
# INFO:root:Epoch[35] Batch [100]	Speed: 5348.69 samples/sec	accuracy=0.610458
# INFO:root:Epoch[35] Train-accuracy=0.616477
# INFO:root:Epoch[35] Time cost=1.337
# INFO:root:Epoch[35] Validation-accuracy=0.663043
# INFO:root:Epoch[36] Batch [100]	Speed: 4493.34 samples/sec	accuracy=0.610458
# INFO:root:Epoch[36] Train-accuracy=0.616477
# INFO:root:Epoch[36] Time cost=1.547
# INFO:root:Epoch[196] Time cost=1.039
# INFO:root:Epoch[196] Validation-accuracy=0.938859
# INFO:root:Epoch[197] Batch [100]	Speed: 6386.91 samples/sec	accuracy=0.912438
# INFO:root:Epoch[197] Train-accuracy=0.954545
# INFO:root:Epoch[197] Time cost=0.880
# INFO:root:Epoch[197] Validation-accuracy=0.914402
# INFO:root:Epoch[198] Batch [100]	Speed: 4991.34 samples/sec	accuracy=0.953280
# INFO:root:Epoch[198] Train-accuracy=0.964962
# INFO:root:Epoch[198] Time cost=1.188
# INFO:root:Epoch[198] Validation-accuracy=0.966033
# INFO:root:Epoch[199] Batch [100]	Speed: 4609.82 samples/sec	accuracy=0.925433
# INFO:root:Epoch[199] Train-accuracy=0.976010
# INFO:root:Epoch[199] Time cost=1.232
# INFO:root:Epoch[199] Validation-accuracy=0.971467

# %% [markdown]
# ### Prediction
#
# After the above training completes, we can evaluate the trained model by running predictions on test data. The following source code computes the prediction probability scores for each test image. *prob[i][j]* is the probability that the *i*-th test image contains the *j*-th output class.

# %%
test_iter = mx.io.NDArrayIter(mnist['test_data'], None, batch_size)
prob = mlp_model.predict(test_iter)
assert prob.shape == (10000, 10)

# %% [markdown]
# Since the dataset also has labels for all test images, we can compute the accuracy metric as follows:

# %%
test_iter = mx.io.NDArrayIter(mnist['test_data'], mnist['test_label'], batch_size)
# predict accuracy of mlp
acc = mx.metric.Accuracy()
mlp_model.score(test_iter, acc)
print(acc)
assert acc.get()[1] > 0.96

# %% [markdown]
# If everything went well, we should see an accuracy value that is around 0.96, which means that we are able to accurately predict the digit in 96% of test images. This is a pretty good result. But as we will see in the next part of this tutorial, we can do a lot better than that.
#
# ### Convolutional Neural Network
#
# Earlier, we briefly touched on a drawback of MLP when we said we need to discard the input image's original shape and flatten it as a vector before we can feed it as input to the MLP's first fully connected layer. Turns out this is an important issue because we don't take advantage of the fact that pixels in the image have natural spatial correlation along the horizontal and vertical axes. A convolutional neural network (CNN) aims to address this problem by using a more structured weight representation. Instead of flattening the image and doing a simple matrix-matrix multiplication, it employs one or more convolutional layers that each performs a 2-D convolution on the input image.
#
# A single convolution layer consists of one or more filters that each play the role of a feature detector. During training, a CNN learns appropriate representations (parameters) for these filters. Similar to MLP, the output from the convolutional layer is transformed by applying a non-linearity. Besides the convolutional layer, another key aspect of a CNN is the pooling layer. A pooling layer serves to make the CNN translation invariant: a digit remains the same even when it is shifted left/right/up/down by a few pixels. A pooling layer reduces a *n x m* patch into a single value to make the network less sensitive to the spatial location. Pooling layer is always included after each conv (+ activation) layer in the CNN.
#
# The following source code defines a convolutional neural network architecture called LeNet. LeNet is a popular network known to work well on digit classification tasks. We will use a slightly different version from the original LeNet implementation, replacing the sigmoid activations with tanh activations for the neurons

# %%
data = mx.sym.var('data')
# first conv layer
conv1 = mx.sym.Convolution(data=data, kernel=(4,4), num_filter=20)
tanh1 = mx.sym.Activation(data=conv1, act_type="relu")
pool1 = mx.sym.Pooling(data=tanh1, pool_type="max", kernel=(2,2), stride=(2,2))
# second conv layer
conv2 = mx.sym.Convolution(data=pool1, kernel=(4,4), num_filter=50)
tanh2 = mx.sym.Activation(data=conv2, act_type="relu")
pool2 = mx.sym.Pooling(data=tanh2, pool_type="max", kernel=(2,2), stride=(2,2))
# first fullc layer
flatten = mx.sym.flatten(data=pool2)
fc1 = mx.symbol.FullyConnected(data=flatten, num_hidden=500)
tanh3 = mx.sym.Activation(data=fc1, act_type="relu")
# second fullc
fc2 = mx.sym.FullyConnected(data=tanh3, num_hidden=2)
# softmax loss
lenet = mx.sym.SoftmaxOutput(data=fc2, name='softmax')

# %% [markdown]
# ![png](https://raw.githubusercontent.com/dmlc/web-data/master/mxnet/image/conv_mnist.png)
#
# **Figure 3:** First conv + pooling layer in LeNet.
#
# Now we train LeNet with the same hyper-parameters as before. Note that, if a GPU is available, we recommend using it. This greatly speeds up computation given that LeNet is more complex and compute-intensive than the previous multilayer perceptron. To do so, we only need to change `mx.cpu()` to `mx.gpu()` and MXNet takes care of the rest. Just like before, we'll stop training after 10 epochs.

# %%
import logging
logging.getLogger().setLevel(logging.DEBUG)  # logging to stdout
# create a trainable module on GPU 0
lenet_model = mx.mod.Module(symbol=lenet, context=mx.cpu())
# train with the same
lenet_model.fit(train_iter,
                eval_data=val_iter,
                optimizer='AdaDelta',
                eval_metric='acc',
                batch_end_callback = mx.callback.Speedometer(batch_size),
                num_epoch=100)
# Out:
# INFO:root:Epoch[0] Batch [50]	Speed: 2262.21 samples/sec	accuracy=0.593750
# INFO:root:Epoch[0] Batch [100]	Speed: 2162.21 samples/sec	accuracy=0.609375
# INFO:root:Epoch[0] Batch [150]	Speed: 2388.18 samples/sec	accuracy=0.603750
# INFO:root:Epoch[0] Train-accuracy=0.679398
# INFO:root:Epoch[0] Time cost=2.498
# INFO:root:Epoch[0] Validation-accuracy=0.830163
# INFO:root:Epoch[1] Batch [50]	Speed: 2437.37 samples/sec	accuracy=0.792279
# INFO:root:Epoch[1] Batch [100]	Speed: 2453.21 samples/sec	accuracy=0.824375
# INFO:root:Epoch[1] Batch [150]	Speed: 2446.15 samples/sec	accuracy=0.866875
# INFO:root:Epoch[1] Train-accuracy=0.880102
# INFO:root:Epoch[1] Time cost=2.631
# INFO:root:Epoch[1] Validation-accuracy=0.919837
# INFO:root:Epoch[2] Batch [50]	Speed: 2452.26 samples/sec	accuracy=0.913603
# INFO:root:Epoch[2] Batch [100]	Speed: 2449.42 samples/sec	accuracy=0.881250
# INFO:root:Epoch[2] Batch [150]	Speed: 2418.77 samples/sec	accuracy=0.917500
# INFO:root:Epoch[2] Train-accuracy=0.894770
# INFO:root:Epoch[2] Time cost=2.666
# INFO:root:Epoch[2] Validation-accuracy=0.892663
# INFO:root:Epoch[3] Batch [50]	Speed: 2224.25 samples/sec	accuracy=0.920343
# INFO:root:Epoch[3] Batch [100]	Speed: 1890.96 samples/sec	accuracy=0.908750
# INFO:root:Epoch[3] Batch [150]	Speed: 2183.41 samples/sec	accuracy=0.928125
# INFO:root:Epoch[3] Train-accuracy=0.917730
# INFO:root:Epoch[3] Time cost=3.009
# INFO:root:Epoch[3] Validation-accuracy=0.937500
# INFO:root:Epoch[4] Batch [50]	Speed: 1588.25 samples/sec	accuracy=0.946691
# INFO:root:Epoch[4] Batch [100]	Speed: 1972.27 samples/sec	accuracy=0.928125
# INFO:root:Epoch[4] Batch [150]	Speed: 2141.46 samples/sec	accuracy=0.943750
# INFO:root:Epoch[4] Train-accuracy=0.938776
# INFO:root:Epoch[4] Time cost=3.283
# INFO:root:Epoch[4] Validation-accuracy=0.945652
# INFO:root:Epoch[5] Batch [50]	Speed: 1761.72 samples/sec	accuracy=0.954044
# INFO:root:Epoch[5] Batch [100]	Speed: 1962.94 samples/sec	accuracy=0.933750
# INFO:root:Epoch[5] Batch [150]	Speed: 2049.30 samples/sec	accuracy=0.940625
# INFO:root:Epoch[5] Train-accuracy=0.943240
# INFO:root:Epoch[5] Time cost=3.318
# INFO:root:Epoch[5] Validation-accuracy=0.959239
# INFO:root:Epoch[6] Batch [50]	Speed: 2050.60 samples/sec	accuracy=0.953431
# INFO:root:Epoch[6] Batch [100]	Speed: 2040.01 samples/sec	accuracy=0.950625
# INFO:root:Epoch[6] Batch [150]	Speed: 2018.21 samples/sec	accuracy=0.936250
# INFO:root:Epoch[6] Train-accuracy=0.956633
# INFO:root:Epoch[6] Time cost=3.129
# INFO:root:Epoch[6] Validation-accuracy=0.940217
# INFO:root:Epoch[7] Batch [50]	Speed: 2062.90 samples/sec	accuracy=0.970588
# INFO:root:Epoch[7] Batch [100]	Speed: 2141.84 samples/sec	accuracy=0.947500
# INFO:root:Epoch[7] Batch [150]	Speed: 2146.38 samples/sec	accuracy=0.965000
# INFO:root:Epoch[7] Train-accuracy=0.951531
# INFO:root:Epoch[7] Time cost=3.180
# INFO:root:Epoch[7] Validation-accuracy=0.956522
# INFO:root:Epoch[8] Batch [50]	Speed: 2198.15 samples/sec	accuracy=0.964461
# INFO:root:Epoch[8] Batch [100]	Speed: 2169.10 samples/sec	accuracy=0.953125
# INFO:root:Epoch[8] Batch [150]	Speed: 2020.38 samples/sec	accuracy=0.963125
# INFO:root:Epoch[8] Train-accuracy=0.951531
# INFO:root:Epoch[8] Time cost=3.327
# INFO:root:Epoch[8] Validation-accuracy=0.910326
# INFO:root:Epoch[9] Batch [50]	Speed: 1395.80 samples/sec	accuracy=0.971814
# INFO:root:Epoch[9] Batch [100]	Speed: 792.25 samples/sec	accuracy=0.962500
# INFO:root:Epoch[9] Batch [150]	Speed: 1114.42 samples/sec	accuracy=0.960000
# INFO:root:Epoch[9] Train-accuracy=0.963648
# INFO:root:Epoch[9] Time cost=6.024
# INFO:root:Epoch[9] Validation-accuracy=0.970109
# INFO:root:Epoch[10] Batch [50]	Speed: 1793.13 samples/sec	accuracy=0.960784
# INFO:root:Epoch[10] Batch [100]	Speed: 1669.90 samples/sec	accuracy=0.965625
# INFO:root:Epoch[10] Batch [150]	Speed: 1883.96 samples/sec	accuracy=0.976250
# INFO:root:Epoch[10] Train-accuracy=0.970026
# INFO:root:Epoch[10] Time cost=3.527
# INFO:root:Epoch[10] Validation-accuracy=0.957880
# INFO:root:Epoch[11] Batch [50]	Speed: 1716.25 samples/sec	accuracy=0.969363
# INFO:root:Epoch[11] Batch [100]	Speed: 1823.02 samples/sec	accuracy=0.962500
# INFO:root:Epoch[11] Batch [150]	Speed: 1916.52 samples/sec	accuracy=0.974375
# INFO:root:Epoch[11] Train-accuracy=0.973852
# INFO:root:Epoch[11] Time cost=3.436
# INFO:root:Epoch[11] Validation-accuracy=0.978261
# INFO:root:Epoch[12] Batch [50]	Speed: 2016.83 samples/sec	accuracy=0.969363
# INFO:root:Epoch[12] Batch [100]	Speed: 1871.15 samples/sec	accuracy=0.961875
# INFO:root:Epoch[12] Batch [150]	Speed: 1851.54 samples/sec	accuracy=0.980000
# INFO:root:Epoch[12] Train-accuracy=0.964923
# INFO:root:Epoch[12] Time cost=3.312
# INFO:root:Epoch[12] Validation-accuracy=0.968750
# INFO:root:Epoch[13] Batch [50]	Speed: 1976.98 samples/sec	accuracy=0.982230
# INFO:root:Epoch[13] Batch [100]	Speed: 2017.92 samples/sec	accuracy=0.974375
# INFO:root:Epoch[13] Batch [150]	Speed: 1926.11 samples/sec	accuracy=0.983750
# INFO:root:Epoch[13] Train-accuracy=0.973214
# INFO:root:Epoch[13] Time cost=3.224
# INFO:root:Epoch[13] Validation-accuracy=0.972826
# INFO:root:Epoch[14] Batch [50]	Speed: 2049.42 samples/sec	accuracy=0.988358
# INFO:root:Epoch[14] Batch [100]	Speed: 2121.66 samples/sec	accuracy=0.973750
# INFO:root:Epoch[14] Batch [150]	Speed: 2143.11 samples/sec	accuracy=0.985625
# INFO:root:Epoch[14] Train-accuracy=0.976403
# INFO:root:Epoch[14] Time cost=3.059
# INFO:root:Epoch[14] Validation-accuracy=0.972826
# INFO:root:Epoch[15] Batch [50]	Speed: 2005.18 samples/sec	accuracy=0.987132
# INFO:root:Epoch[15] Batch [100]	Speed: 1860.82 samples/sec	accuracy=0.979375
# INFO:root:Epoch[15] Batch [150]	Speed: 1900.38 samples/sec	accuracy=0.970625
# INFO:root:Epoch[15] Train-accuracy=0.977679
# INFO:root:Epoch[15] Time cost=3.323
# INFO:root:Epoch[15] Validation-accuracy=0.975543
# INFO:root:Epoch[16] Batch [50]	Speed: 2063.35 samples/sec	accuracy=0.989583
# INFO:root:Epoch[16] Batch [100]	Speed: 2072.01 samples/sec	accuracy=0.976875
# INFO:root:Epoch[16] Batch [150]	Speed: 2090.18 samples/sec	accuracy=0.973125
# INFO:root:Epoch[16] Train-accuracy=0.980230
# INFO:root:Epoch[16] Time cost=3.158
# INFO:root:Epoch[16] Validation-accuracy=0.956522
# INFO:root:Epoch[17] Batch [50]	Speed: 1701.64 samples/sec	accuracy=0.989583
# INFO:root:Epoch[17] Batch [100]	Speed: 2033.90 samples/sec	accuracy=0.972500
# INFO:root:Epoch[17] Batch [150]	Speed: 2020.36 samples/sec	accuracy=0.984375
# INFO:root:Epoch[17] Train-accuracy=0.971939
# INFO:root:Epoch[24] Time cost=3.804
# INFO:root:Epoch[24] Validation-accuracy=0.971467
# INFO:root:Epoch[25] Batch [50]	Speed: 1612.41 samples/sec	accuracy=0.991422
# INFO:root:Epoch[25] Batch [100]	Speed: 1431.58 samples/sec	accuracy=0.981250
# INFO:root:Epoch[25] Batch [150]	Speed: 1589.64 samples/sec	accuracy=0.987500
# INFO:root:Epoch[25] Train-accuracy=0.988520
# INFO:root:Epoch[25] Time cost=4.097
# INFO:root:Epoch[25] Validation-accuracy=0.979620
# INFO:root:Epoch[26] Batch [50]	Speed: 1537.65 samples/sec	accuracy=0.985907
# INFO:root:Epoch[26] Batch [100]	Speed: 1503.13 samples/sec	accuracy=0.981875
# INFO:root:Epoch[26] Batch [150]	Speed: 1827.00 samples/sec	accuracy=0.990625
# INFO:root:Epoch[26] Train-accuracy=0.979592
# INFO:root:Epoch[26] Time cost=3.949
# INFO:root:Epoch[26] Validation-accuracy=0.974185
# INFO:root:Epoch[27] Batch [50]	Speed: 1538.42 samples/sec	accuracy=0.986520
# INFO:root:Epoch[27] Batch [100]	Speed: 1373.48 samples/sec	accuracy=0.986250
# INFO:root:Epoch[27] Batch [150]	Speed: 1321.99 samples/sec	accuracy=0.980625
# INFO:root:Epoch[27] Train-accuracy=0.991709
# INFO:root:Epoch[27] Time cost=4.388
# INFO:root:Epoch[27] Validation-accuracy=0.758152
# INFO:root:Epoch[28] Batch [50]	Speed: 1724.14 samples/sec	accuracy=0.987745
# INFO:root:Epoch[28] Batch [100]	Speed: 1685.26 samples/sec	accuracy=0.986875
# INFO:root:Epoch[28] Batch [150]	Speed: 1678.07 samples/sec	accuracy=0.988750
# INFO:root:Epoch[28] Train-accuracy=0.989796
# INFO:root:Epoch[28] Time cost=3.747
# INFO:root:Epoch[28] Validation-accuracy=0.978261
# INFO:root:Epoch[29] Batch [50]	Speed: 1737.32 samples/sec	accuracy=0.990809
# INFO:root:Epoch[29] Batch [100]	Speed: 1793.62 samples/sec	accuracy=0.981875
# INFO:root:Epoch[29] Batch [150]	Speed: 1552.68 samples/sec	accuracy=0.986250
# INFO:root:Epoch[29] Train-accuracy=0.986607
# INFO:root:Epoch[29] Time cost=3.738
# INFO:root:Epoch[29] Validation-accuracy=0.975543
# INFO:root:Epoch[30] Batch [50]	Speed: 1862.52 samples/sec	accuracy=0.997549
# INFO:root:Epoch[30] Batch [100]	Speed: 1429.62 samples/sec	accuracy=0.985000
# INFO:root:Epoch[30] Batch [150]	Speed: 1767.01 samples/sec	accuracy=0.982500
# INFO:root:Epoch[30] Train-accuracy=0.987883
# INFO:root:Epoch[30] Time cost=3.784
# INFO:root:Epoch[30] Validation-accuracy=0.971467
# INFO:root:Epoch[31] Batch [50]	Speed: 1844.13 samples/sec	accuracy=0.985907
# INFO:root:Epoch[31] Batch [100]	Speed: 1859.92 samples/sec	accuracy=0.989375
# INFO:root:Epoch[31] Batch [150]	Speed: 1746.83 samples/sec	accuracy=0.993750
# INFO:root:Epoch[31] Train-accuracy=0.982781
# INFO:root:Epoch[31] Time cost=3.505
# INFO:root:Epoch[31] Validation-accuracy=0.976902
# INFO:root:Epoch[32] Batch [50]	Speed: 1877.28 samples/sec	accuracy=0.992647
# INFO:root:Epoch[32] Batch [100]	Speed: 1843.54 samples/sec	accuracy=0.994375
# INFO:root:Epoch[32] Batch [150]	Speed: 1811.50 samples/sec	accuracy=0.993750
# INFO:root:Epoch[32] Train-accuracy=0.990434
# INFO:root:Epoch[32] Time cost=3.504
# INFO:root:Epoch[32] Validation-accuracy=0.971467
# INFO:root:Epoch[33] Batch [50]	Speed: 1871.75 samples/sec	accuracy=0.992034
# INFO:root:Epoch[33] Batch [100]	Speed: 1841.92 samples/sec	accuracy=0.980625
# INFO:root:Epoch[33] Batch [150]	Speed: 1760.32 samples/sec	accuracy=0.980000
# INFO:root:Epoch[33] Train-accuracy=0.994260
# INFO:root:Epoch[33] Time cost=3.488
# INFO:root:Epoch[33] Validation-accuracy=0.975543
# INFO:root:Epoch[34] Batch [50]	Speed: 1712.35 samples/sec	accuracy=0.993873
# INFO:root:Epoch[34] Batch [100]	Speed: 1853.87 samples/sec	accuracy=0.990625
# INFO:root:Epoch[34] Batch [150]	Speed: 1864.68 samples/sec	accuracy=0.988125
# INFO:root:Epoch[34] Train-accuracy=0.986607
# INFO:root:Epoch[34] Time cost=3.538
# INFO:root:Epoch[34] Validation-accuracy=0.978261
# INFO:root:Epoch[35] Batch [50]	Speed: 1725.52 samples/sec	accuracy=0.989583
# INFO:root:Epoch[35] Batch [100]	Speed: 1895.61 samples/sec	accuracy=0.981875
# INFO:root:Epoch[35] Batch [150]	Speed: 1950.26 samples/sec	accuracy=0.983125
# INFO:root:Epoch[35] Train-accuracy=0.985332
# INFO:root:Epoch[35] Time cost=3.437
# INFO:root:Epoch[35] Validation-accuracy=0.788043
# INFO:root:Epoch[36] Batch [50]	Speed: 1942.70 samples/sec	accuracy=0.987745
# INFO:root:Epoch[36] Batch [100]	Speed: 1973.60 samples/sec	accuracy=0.989375
# INFO:root:Epoch[36] Batch [150]	Speed: 1772.75 samples/sec	accuracy=0.990000
# INFO:root:Epoch[36] Train-accuracy=0.996173
# INFO:root:Epoch[36] Time cost=3.382
# INFO:root:Epoch[36] Validation-accuracy=0.974185
# INFO:root:Epoch[37] Batch [50]	Speed: 1710.01 samples/sec	accuracy=0.987745
# INFO:root:Epoch[37] Batch [100]	Speed: 1852.27 samples/sec	accuracy=0.983125
# INFO:root:Epoch[37] Batch [150]	Speed: 1859.37 samples/sec	accuracy=0.973750
# INFO:root:Epoch[37] Train-accuracy=0.980230
# INFO:root:Epoch[37] Time cost=3.527
# INFO:root:Epoch[37] Validation-accuracy=0.983696
# INFO:root:Epoch[38] Batch [50]	Speed: 1837.73 samples/sec	accuracy=0.990196
# INFO:root:Epoch[38] Batch [100]	Speed: 1775.78 samples/sec	accuracy=0.990625
# INFO:root:Epoch[38] Batch [150]	Speed: 1839.99 samples/sec	accuracy=0.998125
# INFO:root:Epoch[38] Train-accuracy=0.988520
# INFO:root:Epoch[38] Time cost=3.496
# INFO:root:Epoch[59] Validation-accuracy=0.979620
# INFO:root:Epoch[60] Batch [50]	Speed: 1510.69 samples/sec	accuracy=0.993260
# INFO:root:Epoch[60] Batch [100]	Speed: 1611.88 samples/sec	accuracy=0.993750
# INFO:root:Epoch[60] Batch [150]	Speed: 1646.39 samples/sec	accuracy=1.000000
# INFO:root:Epoch[60] Train-accuracy=1.000000
# INFO:root:Epoch[60] Time cost=4.106
# INFO:root:Epoch[60] Validation-accuracy=0.983696
# INFO:root:Epoch[61] Batch [50]	Speed: 1518.03 samples/sec	accuracy=0.994485
# INFO:root:Epoch[61] Batch [100]	Speed: 1676.45 samples/sec	accuracy=0.997500
# INFO:root:Epoch[61] Batch [150]	Speed: 1608.40 samples/sec	accuracy=0.991875
# INFO:root:Epoch[61] Train-accuracy=0.994260
# INFO:root:Epoch[61] Time cost=3.998
# INFO:root:Epoch[61] Validation-accuracy=0.983696
# INFO:root:Epoch[62] Batch [50]	Speed: 1679.98 samples/sec	accuracy=0.995098
# INFO:root:Epoch[62] Batch [100]	Speed: 1425.19 samples/sec	accuracy=0.992500
# INFO:root:Epoch[62] Batch [150]	Speed: 1553.73 samples/sec	accuracy=0.996250
# INFO:root:Epoch[62] Train-accuracy=0.996811
# INFO:root:Epoch[62] Time cost=4.173
# INFO:root:Epoch[62] Validation-accuracy=0.987772
# INFO:root:Epoch[63] Batch [50]	Speed: 1042.08 samples/sec	accuracy=0.998775
# INFO:root:Epoch[63] Batch [100]	Speed: 1504.12 samples/sec	accuracy=0.993750
# INFO:root:Epoch[63] Batch [150]	Speed: 1827.16 samples/sec	accuracy=0.996250
# INFO:root:Epoch[63] Train-accuracy=0.993622
# INFO:root:Epoch[63] Time cost=4.374
# INFO:root:Epoch[63] Validation-accuracy=0.987772
# INFO:root:Epoch[64] Batch [50]	Speed: 1708.40 samples/sec	accuracy=0.998775
# INFO:root:Epoch[64] Batch [100]	Speed: 1667.82 samples/sec	accuracy=0.995000
# INFO:root:Epoch[64] Batch [150]	Speed: 1730.44 samples/sec	accuracy=0.994375
# INFO:root:Epoch[64] Train-accuracy=0.993622
# INFO:root:Epoch[64] Time cost=3.780
# INFO:root:Epoch[64] Validation-accuracy=0.982337
# INFO:root:Epoch[65] Batch [50]	Speed: 1773.92 samples/sec	accuracy=0.992647
# INFO:root:Epoch[65] Batch [100]	Speed: 1870.91 samples/sec	accuracy=0.990000
# INFO:root:Epoch[65] Batch [150]	Speed: 1856.20 samples/sec	accuracy=0.994375
# INFO:root:Epoch[65] Train-accuracy=0.996811
# INFO:root:Epoch[65] Time cost=3.524
# INFO:root:Epoch[65] Validation-accuracy=0.983696
# INFO:root:Epoch[66] Batch [50]	Speed: 1760.32 samples/sec	accuracy=0.994485
# INFO:root:Epoch[66] Batch [100]	Speed: 1799.34 samples/sec	accuracy=0.988125
# INFO:root:Epoch[66] Batch [150]	Speed: 1898.51 samples/sec	accuracy=0.993750
# INFO:root:Epoch[66] Train-accuracy=0.996173
# INFO:root:Epoch[66] Time cost=3.552
# INFO:root:Epoch[66] Validation-accuracy=0.985054
# INFO:root:Epoch[67] Batch [50]	Speed: 1789.35 samples/sec	accuracy=0.996936
# INFO:root:Epoch[67] Batch [100]	Speed: 1394.58 samples/sec	accuracy=0.993750
# INFO:root:Epoch[67] Batch [150]	Speed: 1435.67 samples/sec	accuracy=0.993750
# INFO:root:Epoch[67] Train-accuracy=0.991071
# INFO:root:Epoch[67] Time cost=4.248
# INFO:root:Epoch[67] Validation-accuracy=0.983696
# INFO:root:Epoch[68] Batch [50]	Speed: 1553.13 samples/sec	accuracy=0.997549
# INFO:root:Epoch[68] Batch [100]	Speed: 1519.64 samples/sec	accuracy=0.994375
# INFO:root:Epoch[68] Batch [150]	Speed: 1584.52 samples/sec	accuracy=0.993750
# INFO:root:Epoch[68] Train-accuracy=0.991709
# INFO:root:Epoch[68] Time cost=4.007
# INFO:root:Epoch[68] Validation-accuracy=0.963315
# INFO:root:Epoch[69] Batch [50]	Speed: 1632.36 samples/sec	accuracy=0.991422
# INFO:root:Epoch[69] Batch [100]	Speed: 1560.02 samples/sec	accuracy=0.996250
# INFO:root:Epoch[69] Batch [150]	Speed: 1580.10 samples/sec	accuracy=0.991250
# INFO:root:Epoch[69] Train-accuracy=0.998724
# INFO:root:Epoch[69] Time cost=3.978
# INFO:root:Epoch[69] Validation-accuracy=0.985054
# INFO:root:Epoch[70] Batch [50]	Speed: 1542.71 samples/sec	accuracy=0.997549
# INFO:root:Epoch[70] Batch [100]	Speed: 1798.48 samples/sec	accuracy=0.986875
# INFO:root:Epoch[70] Batch [150]	Speed: 1791.71 samples/sec	accuracy=1.000000
# INFO:root:Epoch[70] Train-accuracy=0.993622
# INFO:root:Epoch[70] Time cost=3.747
# INFO:root:Epoch[70] Validation-accuracy=0.980978
# INFO:root:Epoch[71] Batch [50]	Speed: 1751.68 samples/sec	accuracy=0.996324
# INFO:root:Epoch[71] Batch [100]	Speed: 1795.41 samples/sec	accuracy=0.989375
# INFO:root:Epoch[71] Batch [150]	Speed: 1436.68 samples/sec	accuracy=0.998750
# INFO:root:Epoch[71] Train-accuracy=0.996811
# INFO:root:Epoch[71] Time cost=4.009
# INFO:root:Epoch[71] Validation-accuracy=0.979620
# INFO:root:Epoch[72] Batch [50]	Speed: 1561.07 samples/sec	accuracy=0.999387
# INFO:root:Epoch[72] Batch [100]	Speed: 1467.86 samples/sec	accuracy=0.995625
# INFO:root:Epoch[72] Batch [150]	Speed: 1493.33 samples/sec	accuracy=0.996875
# INFO:root:Epoch[72] Train-accuracy=0.997449
# INFO:root:Epoch[72] Time cost=4.433
# INFO:root:Epoch[72] Validation-accuracy=0.976902
# INFO:root:Epoch[73] Batch [50]	Speed: 1239.83 samples/sec	accuracy=0.994485
# INFO:root:Epoch[73] Batch [100]	Speed: 1562.57 samples/sec	accuracy=0.994375
# INFO:root:Epoch[73] Batch [150]	Speed: 1862.85 samples/sec	accuracy=0.994375
# INFO:root:Epoch[73] Train-accuracy=0.993622
# INFO:root:Epoch[73] Time cost=4.054
# INFO:root:Epoch[80] Validation-accuracy=0.971467
# INFO:root:Epoch[81] Batch [50]	Speed: 1776.79 samples/sec	accuracy=0.998775
# INFO:root:Epoch[81] Batch [100]	Speed: 1838.16 samples/sec	accuracy=0.995625
# INFO:root:Epoch[81] Batch [150]	Speed: 1837.88 samples/sec	accuracy=1.000000
# INFO:root:Epoch[81] Train-accuracy=1.000000
# INFO:root:Epoch[81] Time cost=3.511
# INFO:root:Epoch[81] Validation-accuracy=0.987772
# INFO:root:Epoch[82] Batch [50]	Speed: 1829.78 samples/sec	accuracy=1.000000
# INFO:root:Epoch[82] Batch [100]	Speed: 1877.99 samples/sec	accuracy=0.999375
# INFO:root:Epoch[82] Batch [150]	Speed: 1790.27 samples/sec	accuracy=0.998125
# INFO:root:Epoch[82] Train-accuracy=1.000000
# INFO:root:Epoch[82] Time cost=3.463
# INFO:root:Epoch[82] Validation-accuracy=0.983696
# INFO:root:Epoch[83] Batch [50]	Speed: 1825.48 samples/sec	accuracy=0.998775
# INFO:root:Epoch[83] Batch [100]	Speed: 1898.58 samples/sec	accuracy=0.999375
# INFO:root:Epoch[83] Batch [150]	Speed: 1816.82 samples/sec	accuracy=0.999375
# INFO:root:Epoch[83] Train-accuracy=0.997449
# INFO:root:Epoch[83] Time cost=3.449
# INFO:root:Epoch[83] Validation-accuracy=0.979620
# INFO:root:Epoch[84] Batch [50]	Speed: 1952.88 samples/sec	accuracy=0.996936
# INFO:root:Epoch[84] Batch [100]	Speed: 1944.02 samples/sec	accuracy=0.995625
# INFO:root:Epoch[84] Batch [150]	Speed: 1899.96 samples/sec	accuracy=0.999375
# INFO:root:Epoch[84] Train-accuracy=1.000000
# INFO:root:Epoch[84] Time cost=3.332
# INFO:root:Epoch[84] Validation-accuracy=0.991848
# INFO:root:Epoch[85] Batch [50]	Speed: 1553.79 samples/sec	accuracy=0.995711
# INFO:root:Epoch[85] Batch [100]	Speed: 1448.48 samples/sec	accuracy=0.997500
# INFO:root:Epoch[85] Batch [150]	Speed: 1465.80 samples/sec	accuracy=0.997500
# INFO:root:Epoch[85] Train-accuracy=0.991709
# INFO:root:Epoch[85] Time cost=4.380
# INFO:root:Epoch[85] Validation-accuracy=0.980978
# INFO:root:Epoch[86] Batch [50]	Speed: 1573.60 samples/sec	accuracy=0.996324
# INFO:root:Epoch[86] Batch [100]	Speed: 1486.19 samples/sec	accuracy=0.995000
# INFO:root:Epoch[86] Batch [150]	Speed: 1488.00 samples/sec	accuracy=0.993750
# INFO:root:Epoch[86] Train-accuracy=0.996173
# INFO:root:Epoch[86] Time cost=4.261
# INFO:root:Epoch[86] Validation-accuracy=0.985054
# INFO:root:Epoch[87] Batch [50]	Speed: 1580.46 samples/sec	accuracy=0.996324
# INFO:root:Epoch[87] Batch [100]	Speed: 1568.00 samples/sec	accuracy=0.996250
# INFO:root:Epoch[87] Batch [150]	Speed: 1517.43 samples/sec	accuracy=0.998125
# INFO:root:Epoch[87] Train-accuracy=0.998724
# INFO:root:Epoch[87] Time cost=4.159
# INFO:root:Epoch[87] Validation-accuracy=0.985054
# INFO:root:Epoch[88] Batch [50]	Speed: 1412.80 samples/sec	accuracy=0.999387
# INFO:root:Epoch[88] Batch [100]	Speed: 1148.27 samples/sec	accuracy=0.995625
# INFO:root:Epoch[88] Batch [150]	Speed: 1535.74 samples/sec	accuracy=0.999375
# INFO:root:Epoch[88] Train-accuracy=0.985969
# INFO:root:Epoch[88] Time cost=4.799
# INFO:root:Epoch[88] Validation-accuracy=0.976902
# INFO:root:Epoch[89] Batch [50]	Speed: 1457.64 samples/sec	accuracy=0.997549
# INFO:root:Epoch[89] Batch [100]	Speed: 1578.93 samples/sec	accuracy=0.993750
# INFO:root:Epoch[89] Batch [150]	Speed: 1755.11 samples/sec	accuracy=0.994375
# INFO:root:Epoch[89] Train-accuracy=0.996811
# INFO:root:Epoch[89] Time cost=3.905
# INFO:root:Epoch[89] Validation-accuracy=0.983696
# INFO:root:Epoch[90] Batch [50]	Speed: 1817.57 samples/sec	accuracy=1.000000
# INFO:root:Epoch[90] Batch [100]	Speed: 1854.40 samples/sec	accuracy=0.996875
# INFO:root:Epoch[90] Batch [150]	Speed: 1849.55 samples/sec	accuracy=0.993125
# INFO:root:Epoch[90] Train-accuracy=0.996173
# INFO:root:Epoch[90] Time cost=3.467
# INFO:root:Epoch[90] Validation-accuracy=0.985054
# INFO:root:Epoch[91] Batch [50]	Speed: 1814.04 samples/sec	accuracy=0.996324
# INFO:root:Epoch[91] Batch [100]	Speed: 1766.17 samples/sec	accuracy=0.997500
# INFO:root:Epoch[91] Batch [150]	Speed: 1747.19 samples/sec	accuracy=0.999375
# INFO:root:Epoch[91] Train-accuracy=0.997449
# INFO:root:Epoch[91] Time cost=3.616
# INFO:root:Epoch[91] Validation-accuracy=0.986413
# INFO:root:Epoch[92] Batch [50]	Speed: 1799.35 samples/sec	accuracy=0.998775
# INFO:root:Epoch[92] Batch [100]	Speed: 1834.26 samples/sec	accuracy=0.996250
# INFO:root:Epoch[92] Batch [150]	Speed: 1638.25 samples/sec	accuracy=0.996875
# INFO:root:Epoch[92] Train-accuracy=0.998724
# INFO:root:Epoch[92] Time cost=3.658
# INFO:root:Epoch[92] Validation-accuracy=0.979620
# INFO:root:Epoch[93] Batch [50]	Speed: 1679.81 samples/sec	accuracy=0.999387
# INFO:root:Epoch[93] Batch [100]	Speed: 1805.18 samples/sec	accuracy=0.996250
# INFO:root:Epoch[93] Batch [150]	Speed: 1807.18 samples/sec	accuracy=0.995625
# INFO:root:Epoch[93] Train-accuracy=0.999362
# INFO:root:Epoch[93] Time cost=3.626
# INFO:root:Epoch[93] Validation-accuracy=0.983696
# INFO:root:Epoch[94] Batch [50]	Speed: 1726.14 samples/sec	accuracy=0.998775
# INFO:root:Epoch[94] Batch [100]	Speed: 1822.18 samples/sec	accuracy=1.000000
# INFO:root:Epoch[94] Batch [150]	Speed: 1804.53 samples/sec	accuracy=1.000000
# INFO:root:Epoch[94] Train-accuracy=0.998087
# INFO:root:Epoch[94] Time cost=3.609
# INFO:root:Epoch[94] Validation-accuracy=0.985054
# INFO:root:Epoch[95] Batch [50]	Speed: 1731.73 samples/sec	accuracy=0.997549
# INFO:root:Epoch[95] Batch [100]	Speed: 1690.43 samples/sec	accuracy=0.998125
# INFO:root:Epoch[95] Batch [150]	Speed: 1659.67 samples/sec	accuracy=0.999375
# INFO:root:Epoch[95] Train-accuracy=0.996811
# INFO:root:Epoch[95] Time cost=3.785
# INFO:root:Epoch[95] Validation-accuracy=0.985054
# INFO:root:Epoch[96] Batch [50]	Speed: 1483.20 samples/sec	accuracy=0.994485
# INFO:root:Epoch[96] Batch [100]	Speed: 1426.22 samples/sec	accuracy=1.000000
# INFO:root:Epoch[96] Batch [150]	Speed: 1343.62 samples/sec	accuracy=0.998125
# INFO:root:Epoch[96] Train-accuracy=0.998087
# INFO:root:Epoch[96] Time cost=4.463
# INFO:root:Epoch[96] Validation-accuracy=0.989130
# INFO:root:Epoch[97] Batch [50]	Speed: 1747.61 samples/sec	accuracy=0.999387
# INFO:root:Epoch[97] Batch [100]	Speed: 1499.68 samples/sec	accuracy=1.000000
# INFO:root:Epoch[97] Batch [150]	Speed: 1614.31 samples/sec	accuracy=0.995000
# INFO:root:Epoch[97] Train-accuracy=0.999362
# INFO:root:Epoch[97] Time cost=3.946
# INFO:root:Epoch[97] Validation-accuracy=0.980978
# INFO:root:Epoch[98] Batch [50]	Speed: 1131.89 samples/sec	accuracy=0.999387
# INFO:root:Epoch[98] Batch [100]	Speed: 1046.16 samples/sec	accuracy=0.997500
# INFO:root:Epoch[98] Batch [150]	Speed: 1404.85 samples/sec	accuracy=0.997500
# INFO:root:Epoch[98] Train-accuracy=0.998087
# INFO:root:Epoch[98] Time cost=4.970
# INFO:root:Epoch[98] Validation-accuracy=0.978261
# INFO:root:Epoch[99] Batch [50]	Speed: 1429.12 samples/sec	accuracy=0.996936
# INFO:root:Epoch[99] Batch [100]	Speed: 1288.64 samples/sec	accuracy=0.996875
# INFO:root:Epoch[99] Batch [150]	Speed: 1354.01 samples/sec	accuracy=0.998750
# INFO:root:Epoch[99] Train-accuracy=0.994898
# INFO:root:Epoch[99] Time cost=4.719
# INFO:root:Epoch[99] Validation-accuracy=0.980978

# %% [markdown]
# ### Prediction
#
# Finally, we'll use the trained LeNet model to generate predictions for the test data.

# %%
test_iter = mx.io.NDArrayIter(mnist['test_data'], None, batch_size)
prob = lenet_model.predict(test_iter)
test_iter = mx.io.NDArrayIter(mnist['test_data'], mnist['test_label'], batch_size)
# predict accuracy for lenet
acc = mx.metric.Accuracy()
lenet_model.score(test_iter, acc)
print(acc)
assert acc.get()[1] > 0.98
# Out:
# EvalMetric: {'accuracy': 0.98699999999999999}

# %% [markdown]
# If all went well, we should see a higher accuracy metric for predictions made using LeNet. With CNN we should be able to correctly predict around 98% of all test images.
#
# ## Summary
#
# In this tutorial, we have learned how to use MXNet to solve a standard computer vision problem: classifying images of hand written digits. You have seen how to quickly and easily build, train and evaluate models such as MLP and CNN with MXNet.
#
# <!-- INSERT SOURCE DOWNLOAD BUTTONS -->
